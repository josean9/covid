# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Modificamos los parámetros de los gráficos en matplotlib
from matplotlib.pyplot import rcParams

rcParams['figure.figsize'] = 12, 6 # el primer dígito es el ancho y el segundo el alto
rcParams["font.weight"] = "bold"
rcParams["font.size"] = 10
rcParams["axes.labelweight"] = "bold"

df_covid = pd.read_csv("CoviData.csv")

# %%
df_covid
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1                   97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
df_covid2 = df_covid[df_covid["DATE_DIED"] != "9999-99-99"] #eliminamos las filas con fechas raras
df_covid2
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1                   97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1047635      1            13    2             2  18/07/2020        1
# 1047636      1            13    2             1  26/07/2020       97
# 1047637      1            13    1             1  27/07/2020       97
# 1047638      1            13    2             2  29/07/2020        1
# 1047639      1            13    2             2  29/07/2020        2
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
df_covid2.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  76942.000000  76942.000000  76942.000000  76942.000000  76942.000000
# mean       1.439123      7.008747      1.643862      1.910634     12.774181
# std        0.496283      3.668800      0.478860      0.285273     30.751365
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      4.000000      1.000000      2.000000      1.000000
# 50%        1.000000      4.000000      2.000000      2.000000      2.000000
# 75%        2.000000     12.000000      2.000000      2.000000      2.000000
# max        2.000000     13.000000      2.000000      2.000000     99.000000
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  76942.000000  76942.000000  76942.000000  76942.000000  76942.000000
# mean       2.224520     61.068545     63.249292      2.544709      2.834850
# ...

# %%
df_covid2["DATE_DIED"].value_counts()
# Out:
# 06/07/2020    1000
# 07/07/2020     996
# 13/07/2020     990
# 16/06/2020     979
# 16/07/2020     938
#               ...
# 11/02/2021       1
# 10/02/2021       1
# 01/02/2021       1
# 25/01/2021       1
# 22/04/2021       1
# Name: DATE_DIED, Length: 401, dtype: int64

# %%
for i in df_covid2['DATE_DIED']:
    print(i[3:5])
df_covid2['DATE_DIED'] = pd.to_datetime(df_covid2['DATE_DIED'], format='%d/%m/%Y')
# Out:
# 06
# 06
# 06
# 06
# 02
# 04
# 05
# 05
# 07
# 01
# 01
# 01
# 01
# 02
# 02
# 02
# 02
# 02
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 03
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 04
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# 05
# ...
